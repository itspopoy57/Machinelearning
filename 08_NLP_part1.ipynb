# %% [markdown]
# <a href="https://colab.research.google.com/github/itspopoy57/Machinelearning/blob/main/08_NLP_part1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #NLP

# %% [markdown]
# #Standard Architecture of RNN
# ![image.png](data:image/png;base64,...)

# %%
# !wget https://github.com/itspopoy57/Machinelearning/blob/main/extras/helper_func.py
# Out:
# --2023-11-11 20:49:06--  https://github.com/itspopoy57/Machinelearning/blob/main/extras/helper_func.py
# Resolving github.com (github.com)... 20.27.177.113
# Connecting to github.com (github.com)|20.27.177.113|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 52504 (51K) [text/plain]
# Saving to: ‘helper_func.py.1’
#
# helper_func.py.1    100%[===================>]  51.27K  --.-KB/s    in 0.09s
#
# 2023-11-11 20:49:06 (553 KB/s) - ‘helper_func.py.1’ saved [52504/52504]

# %%
from
